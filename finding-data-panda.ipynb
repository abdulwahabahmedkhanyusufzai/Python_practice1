# %% [markdown]
# # Loading Local Data in Google Colab
#
# Since you are running this in **Google Colab**, the code runs on Google's cloud servers, not your local computer. This means the notebook cannot see `anime.csv` on your computer unless you **upload it** first.
#
# ## Option 1: Drag and Drop
# 1. Click the file folder icon on the left sidebar in Colab.
# 2. Drag `anime.csv` from your computer into that sidebar.
#
# ## Option 2: Upload via Code
# Run the cell below to verify if the file is present, or upload it if it's missing.

# %%
import pandas as pd
import os

file_name = 'anime.csv'

# Check if running in Colab and file is missing
try:
    from google.colab import files
    if not os.path.exists(file_name):
        print(f"{file_name} not found. Processing upload request...")
        print("Please select 'anime.csv' from your computer in the button below:")
        uploaded = files.upload()
        # The key in 'uploaded' dict is the filename
        if file_name not in uploaded.keys() and len(uploaded) > 0:
             # warn if they uploaded something else by mistake, or just use the first file
             print(f"Note: You uploaded {list(uploaded.keys())[0]}, but we were looking for {file_name}.")
    else:
        print(f"{file_name} is already uploaded!")
except ImportError:
    print("Not running in Google Colab (or google.colab module not found).")

# Now load the data
if os.path.exists(file_name):
    try:
        df = pd.read_csv(file_name)
        print("\nSuccess! Data loaded.")
        display(df.head())
    except Exception as e:
        print(f"Error reading file: {e}")
else:
    print(f"\nError: {file_name} not found. Please upload it using the File sidebar or the code above.")
# Out:
# anime.csv not found. Processing upload request...
# Please select 'anime.csv' from your computer in the button below:
#      <input type="file" id="files-380a4b1e-86cd-49fe-a0e5-5ac80356ac8d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-380a4b1e-86cd-49fe-a0e5-5ac80356ac8d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...
