# %%
import numpy as np

arr = np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
#vectors
l=[[1,2,3],[4,5,6],[7,8,9]]
arr_l = np.array(l)
print(arr_l)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]
